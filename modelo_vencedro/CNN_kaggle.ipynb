# %%
import os
import sys
import platform

print(f"Python version: {sys.version}")
print(f"OS: {platform.platform()}")
print(f"CPU Cores: {os.cpu_count()}")
# Out:
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# OS: Linux-6.6.122+-x86_64-with-glibc2.35
# CPU Cores: 12

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

if device.type == 'cuda':
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"CUDA Capability: {torch.cuda.get_device_capability(0)}")
    print(f"Total VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

    # Habilitar o modo de alta performance (TF32) nas arquiteturas Ampere/Hopper
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True
    torch.backends.cudnn.benchmark = True # Otimiza convs para tamanhos estáticos
# Out:
# Using device: cuda
# GPU Name: NVIDIA A100-SXM4-80GB
# CUDA Capability: (8, 0)
# Total VRAM: 85.09 GB

# %%
import random
import numpy as np

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # torch.backends.cudnn.deterministic = True  # Desativado para não perder performance extrema

set_seed(42)
print("Global seed set to 42.")
# Out:
# Global seed set to 42.

# %%
import torchvision
import torchvision.transforms as transforms

# Normalização padrão para CIFAR-100
mean = (0.5071, 0.4867, 0.4408)
std = (0.2675, 0.2565, 0.2761)

# Transforms de Treino (RandAugment SOTA)
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.RandAugment(num_ops=2, magnitude=9), # RandAugment para grande generalização
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
    #transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value=0) # Opcional: Cutout em cima do RandAugment
])

# Transforms de Validação
transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

train_dataset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_val)

print(f"Train size: {len(train_dataset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# 100%|██████████| 169M/169M [00:08<00:00, 19.8MB/s]
# Train size: 50000
# Test size: 10000

# %%
BATCH_SIZE = 256
NUM_WORKERS = os.cpu_count() or 4

# === OTIMIZACAO AQUI (persistent_workers e prefetch_factor adicionados abaixo) ===
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=NUM_WORKERS, pin_memory=True, drop_last=True, persistent_workers=True, prefetch_factor=4
)

test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=NUM_WORKERS, pin_memory=True, persistent_workers=True, prefetch_factor=4
)

print(f"DataLoaders otimizados criados com Batch Size = {BATCH_SIZE} e Workers = {NUM_WORKERS}")
# Out:
# DataLoaders otimizados criados com Batch Size = 256 e Workers = 12

# %%
def rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = int(W * cut_rat)
    cut_h = int(H * cut_rat)

    # uniform
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# %%
import torch.nn as nn
import torch.nn.functional as F

class BasicBlock(nn.Module):
    def __init__(self, in_planes, out_planes, stride, dropRate=0.0):
        super(BasicBlock, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.conv1 = nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                               padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_planes)
        self.relu2 = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_planes, out_planes, kernel_size=3, stride=1,
                               padding=1, bias=False)
        self.droprate = dropRate
        self.equalInOut = (in_planes == out_planes)
        self.convShortcut = (not self.equalInOut) and nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride,
                               padding=0, bias=False) or None

    def forward(self, x):
        if not self.equalInOut:
            x = self.relu1(self.bn1(x))
        else:
            out = self.relu1(self.bn1(x))
        out = self.relu2(self.bn2(self.conv1(out if self.equalInOut else x)))
        if self.droprate > 0:
            out = F.dropout(out, p=self.droprate, training=self.training)
        out = self.conv2(out)
        return torch.add(x if self.equalInOut else self.convShortcut(x), out)

class NetworkBlock(nn.Module):
    def __init__(self, nb_layers, in_planes, out_planes, block, stride, dropRate=0.0):
        super(NetworkBlock, self).__init__()
        self.layer = self._make_layer(block, in_planes, out_planes, nb_layers, stride, dropRate)
    def _make_layer(self, block, in_planes, out_planes, nb_layers, stride, dropRate):
        layers = []
        for i in range(nb_layers):
            layers.append(block(i == 0 and in_planes or out_planes, out_planes, i == 0 and stride or 1, dropRate))
        return nn.Sequential(*layers)
    def forward(self, x):
        return self.layer(x)

class WideResNet(nn.Module):
    def __init__(self, depth, num_classes, widen_factor=1, dropRate=0.0):
        super(WideResNet, self).__init__()
        nChannels = [16, 16*widen_factor, 32*widen_factor, 64*widen_factor]
        assert (depth - 4) % 6 == 0, 'depth should be 6n+4'
        n = (depth - 4) // 6
        block = BasicBlock
        # 1st conv before any network block
        self.conv1 = nn.Conv2d(3, nChannels[0], kernel_size=3, stride=1,
                               padding=1, bias=False)
        # 1st block
        self.block1 = NetworkBlock(n, nChannels[0], nChannels[1], block, 1, dropRate)
        # 2nd block
        self.block2 = NetworkBlock(n, nChannels[1], nChannels[2], block, 2, dropRate)
        # 3rd block
        self.block3 = NetworkBlock(n, nChannels[2], nChannels[3], block, 2, dropRate)
        # global average pooling and classifier
        self.bn1 = nn.BatchNorm2d(nChannels[3])
        self.relu = nn.ReLU(inplace=True)
        self.fc = nn.Linear(nChannels[3], num_classes)
        self.nChannels = nChannels[3]

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.bias.data.zero_()

    def forward(self, x):
        out = self.conv1(x)
        out = self.block1(out)
        out = self.block2(out)
        out = self.block3(out)
        out = self.relu(self.bn1(out))
        out = F.avg_pool2d(out, 8)
        out = out.view(-1, self.nChannels)
        return self.fc(out)

model = WideResNet(depth=28, num_classes=100, widen_factor=10, dropRate=0.3)
model = model.to(device)
# === OTIMIZACAO AQUI: channels_last ===
model = model.to(memory_format=torch.channels_last)
# === OTIMIZACAO AQUI: torch.compile ===
model = torch.compile(model, mode='reduce-overhead')

# Total de parâmetros deve ficar em torno de 36.5M
print(f"Total parameters: {sum(p.numel() for p in model.parameters()) / 1e6:.2f} M")
# Out:
# Total parameters: 36.54 M

# %%
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

# %%
EPOCHS = 100
LEARNING_RATE = 0.15

optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=0.9, weight_decay=5e-4, nesterov=True)

steps_per_epoch = len(train_loader)
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer,
    max_lr=LEARNING_RATE,
    epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch,
    pct_start=0.1,
    anneal_strategy='cos',
    div_factor=10.0,
    final_div_factor=1e4
)

# %%
import time
from torch.amp import autocast, GradScaler
from torchmetrics import Accuracy

scaler = GradScaler('cuda')
accuracy_metric = Accuracy(task="multiclass", num_classes=100).to(device)
top5_accuracy_metric = Accuracy(task="multiclass", num_classes=100, top_k=5).to(device)

best_acc = 0.0
cutmix_prob = 0.5

print("Iniciando Treinamento...")
for epoch in range(EPOCHS):
    model.train()
    train_loss = 0
    correct = 0
    total = 0

    start_time = time.time()
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
            # === OTIMIZACAO AQUI: Alinhando input da imagem para channels_last ===
        inputs = inputs.to(memory_format=torch.channels_last)

        # CutMix implementation
        r = np.random.rand(1)
        if r < cutmix_prob:
            # generate mixed sample
            lam = np.random.beta(1.0, 1.0)
            rand_index = torch.randperm(inputs.size()[0]).cuda()
            target_a = targets
            target_b = targets[rand_index]
            bbx1, bby1, bbx2, bby2 = rand_bbox(inputs.size(), lam)
            inputs[:, :, bbx1:bbx2, bby1:bby2] = inputs[rand_index, :, bbx1:bbx2, bby1:bby2]
            lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (inputs.size()[-1] * inputs.size()[-2]))

            optimizer.zero_grad()
            with autocast('cuda'):
                outputs = model(inputs)
                loss = criterion(outputs, target_a) * lam + criterion(outputs, target_b) * (1. - lam)
        else:
            optimizer.zero_grad()
            with autocast('cuda'):
                outputs = model(inputs)
                loss = criterion(outputs, targets)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        scheduler.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    # --- Validação ---
    model.eval()
    val_loss = 0
    accuracy_metric.reset()
    top5_accuracy_metric.reset()

    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            # === OTIMIZACAO AQUI: Alinhando input da imagem para channels_last ===
            inputs = inputs.to(memory_format=torch.channels_last)
            with autocast('cuda'):
                outputs = model(inputs)
                loss = criterion(outputs, targets)

            val_loss += loss.item()
            accuracy_metric.update(outputs, targets)
            top5_accuracy_metric.update(outputs, targets)

    val_acc = accuracy_metric.compute().item() * 100
    val_top5 = top5_accuracy_metric.compute().item() * 100


    epoch_time = time.time() - start_time

    print(f'Epoch [{epoch+1}/{EPOCHS}] | Time: {epoch_time:.0f}s | '
          f'Loss: {train_loss/len(train_loader):.4f} | '
          f'Val Loss: {val_loss/len(test_loader):.4f} | '
          f'Val Acc: {val_acc:.2f}% | Val Top5: {val_top5:.2f}% | '
          f'LR: {scheduler.get_last_lr()[0]:.5f}')

    if val_acc > best_acc:
        best_acc = val_acc
        torch.save(model.state_dict(), 'best_wrn28_10_cifar100.pth')
        print(f'>>> Melhor modelo salvo! Acurácia: {best_acc:.2f}%')
# Out:
# Iniciando Treinamento...
# Epoch [1/100] | Time: 40s | Loss: 4.4742 | Val Loss: 4.3549 | Val Acc: 5.44% | Val Top5: 19.55% | LR: 0.01831
# >>> Melhor modelo salvo! Acurácia: 5.44%
# Epoch [2/100] | Time: 17s | Loss: 4.2123 | Val Loss: 4.2469 | Val Acc: 9.09% | Val Top5: 30.38% | LR: 0.02790
# >>> Melhor modelo salvo! Acurácia: 9.09%
# Epoch [3/100] | Time: 17s | Loss: 4.0026 | Val Loss: 3.7565 | Val Acc: 17.03% | Val Top5: 43.17% | LR: 0.04285
# >>> Melhor modelo salvo! Acurácia: 17.03%
# Epoch [4/100] | Time: 17s | Loss: 3.8146 | Val Loss: 3.4717 | Val Acc: 22.50% | Val Top5: 51.32% | LR: 0.06168
# >>> Melhor modelo salvo! Acurácia: 22.50%
# Epoch [5/100] | Time: 17s | Loss: 3.5630 | Val Loss: 3.4258 | Val Acc: 25.25% | Val Top5: 57.52% | LR: 0.08255
# >>> Melhor modelo salvo! Acurácia: 25.25%
# Epoch [6/100] | Time: 17s | Loss: 3.3693 | Val Loss: 3.1586 | Val Acc: 30.19% | Val Top5: 60.26% | LR: 0.10342
# >>> Melhor modelo salvo! Acurácia: 30.19%
# Epoch [7/100] | Time: 17s | Loss: 3.2212 | Val Loss: 3.0386 | Val Acc: 32.62% | Val Top5: 65.21% | LR: 0.12224
# >>> Melhor modelo salvo! Acurácia: 32.62%
# Epoch [8/100] | Time: 17s | Loss: 3.1194 | Val Loss: 2.6411 | Val Acc: 43.28% | Val Top5: 75.03% | LR: 0.13716
# >>> Melhor modelo salvo! Acurácia: 43.28%
# Epoch [9/100] | Time: 17s | Loss: 3.0880 | Val Loss: 2.6334 | Val Acc: 43.00% | Val Top5: 74.82% | LR: 0.14673
# Epoch [10/100] | Time: 17s | Loss: 2.9351 | Val Loss: 2.5293 | Val Acc: 45.63% | Val Top5: 77.42% | LR: 0.15000
# >>> Melhor modelo salvo! Acurácia: 45.63%
# Epoch [11/100] | Time: 17s | Loss: 2.9503 | Val Loss: 2.6064 | Val Acc: 43.09% | Val Top5: 76.37% | LR: 0.14995
# Epoch [12/100] | Time: 17s | Loss: 2.8915 | Val Loss: 2.3870 | Val Acc: 49.56% | Val Top5: 79.69% | LR: 0.14982
# >>> Melhor modelo salvo! Acurácia: 49.56%
# Epoch [13/100] | Time: 17s | Loss: 2.8507 | Val Loss: 2.3458 | Val Acc: 50.99% | Val Top5: 81.45% | LR: 0.14959
# >>> Melhor modelo salvo! Acurácia: 50.99%
# Epoch [14/100] | Time: 17s | Loss: 2.7284 | Val Loss: 2.3548 | Val Acc: 51.28% | Val Top5: 80.47% | LR: 0.14927
# >>> Melhor modelo salvo! Acurácia: 51.28%
# Epoch [15/100] | Time: 17s | Loss: 2.7387 | Val Loss: 2.2034 | Val Acc: 55.42% | Val Top5: 83.95% | LR: 0.14886
# >>> Melhor modelo salvo! Acurácia: 55.42%
# Epoch [16/100] | Time: 17s | Loss: 2.6691 | Val Loss: 2.2254 | Val Acc: 54.54% | Val Top5: 84.06% | LR: 0.14836
# Epoch [17/100] | Time: 17s | Loss: 2.6649 | Val Loss: 2.1447 | Val Acc: 56.70% | Val Top5: 85.37% | LR: 0.14777
# >>> Melhor modelo salvo! Acurácia: 56.70%
# Epoch [18/100] | Time: 17s | Loss: 2.5629 | Val Loss: 2.2540 | Val Acc: 54.02% | Val Top5: 83.33% | LR: 0.14709
# Epoch [19/100] | Time: 17s | Loss: 2.5730 | Val Loss: 2.1187 | Val Acc: 57.56% | Val Top5: 85.94% | LR: 0.14633
# >>> Melhor modelo salvo! Acurácia: 57.56%
# Epoch [20/100] | Time: 17s | Loss: 2.5448 | Val Loss: 2.0286 | Val Acc: 60.20% | Val Top5: 87.84% | LR: 0.14547
# >>> Melhor modelo salvo! Acurácia: 60.20%
# Epoch [21/100] | Time: 17s | Loss: 2.5518 | Val Loss: 2.1227 | Val Acc: 57.58% | Val Top5: 85.47% | LR: 0.14453
# Epoch [22/100] | Time: 16s | Loss: 2.5126 | Val Loss: 2.2846 | Val Acc: 53.69% | Val Top5: 82.61% | LR: 0.14351
# Epoch [23/100] | Time: 16s | Loss: 2.5327 | Val Loss: 2.0765 | Val Acc: 59.63% | Val Top5: 86.31% | LR: 0.14240
# Epoch [24/100] | Time: 16s | Loss: 2.4433 | Val Loss: 2.1657 | Val Acc: 56.76% | Val Top5: 84.59% | LR: 0.14121
# Epoch [25/100] | Time: 16s | Loss: 2.4352 | Val Loss: 2.0952 | Val Acc: 59.60% | Val Top5: 85.98% | LR: 0.13995
# Epoch [26/100] | Time: 16s | Loss: 2.3409 | Val Loss: 2.0117 | Val Acc: 60.49% | Val Top5: 87.80% | LR: 0.13860
# >>> Melhor modelo salvo! Acurácia: 60.49%
# Epoch [27/100] | Time: 17s | Loss: 2.4955 | Val Loss: 2.0482 | Val Acc: 60.51% | Val Top5: 87.08% | LR: 0.13717
# >>> Melhor modelo salvo! Acurácia: 60.51%
# Epoch [28/100] | Time: 17s | Loss: 2.4363 | Val Loss: 1.9937 | Val Acc: 61.70% | Val Top5: 87.76% | LR: 0.13567
# >>> Melhor modelo salvo! Acurácia: 61.70%
# Epoch [29/100] | Time: 16s | Loss: 2.4157 | Val Loss: 2.0292 | Val Acc: 60.53% | Val Top5: 86.75% | LR: 0.13409
# Epoch [30/100] | Time: 17s | Loss: 2.4931 | Val Loss: 1.9990 | Val Acc: 61.01% | Val Top5: 87.20% | LR: 0.13244
# Epoch [31/100] | Time: 16s | Loss: 2.3551 | Val Loss: 1.9764 | Val Acc: 62.71% | Val Top5: 88.43% | LR: 0.13073
# >>> Melhor modelo salvo! Acurácia: 62.71%
# Epoch [32/100] | Time: 17s | Loss: 2.3490 | Val Loss: 2.0169 | Val Acc: 61.29% | Val Top5: 86.89% | LR: 0.12894
# Epoch [33/100] | Time: 16s | Loss: 2.2729 | Val Loss: 1.8658 | Val Acc: 66.09% | Val Top5: 89.89% | LR: 0.12709
# >>> Melhor modelo salvo! Acurácia: 66.09%
# Epoch [34/100] | Time: 16s | Loss: 2.3187 | Val Loss: 1.8990 | Val Acc: 64.87% | Val Top5: 89.29% | LR: 0.12518
# Epoch [35/100] | Time: 17s | Loss: 2.3832 | Val Loss: 1.9300 | Val Acc: 63.61% | Val Top5: 88.50% | LR: 0.12320
# Epoch [36/100] | Time: 17s | Loss: 2.3634 | Val Loss: 1.9491 | Val Acc: 62.42% | Val Top5: 88.69% | LR: 0.12116
# Epoch [37/100] | Time: 16s | Loss: 2.2599 | Val Loss: 1.9070 | Val Acc: 65.00% | Val Top5: 89.01% | LR: 0.11907
# Epoch [38/100] | Time: 16s | Loss: 2.3285 | Val Loss: 1.9646 | Val Acc: 63.05% | Val Top5: 88.14% | LR: 0.11693
# Epoch [39/100] | Time: 16s | Loss: 2.3344 | Val Loss: 1.9136 | Val Acc: 65.05% | Val Top5: 88.43% | LR: 0.11473
# Epoch [40/100] | Time: 17s | Loss: 2.2460 | Val Loss: 1.9734 | Val Acc: 63.21% | Val Top5: 88.37% | LR: 0.11249
# Epoch [41/100] | Time: 16s | Loss: 2.2468 | Val Loss: 1.9313 | Val Acc: 64.34% | Val Top5: 88.53% | LR: 0.11020
# Epoch [42/100] | Time: 16s | Loss: 2.3296 | Val Loss: 1.9240 | Val Acc: 63.98% | Val Top5: 88.52% | LR: 0.10787
# Epoch [43/100] | Time: 16s | Loss: 2.2510 | Val Loss: 1.9687 | Val Acc: 64.26% | Val Top5: 88.15% | LR: 0.10549
# Epoch [44/100] | Time: 16s | Loss: 2.2756 | Val Loss: 1.9607 | Val Acc: 62.83% | Val Top5: 88.21% | LR: 0.10308
# Epoch [45/100] | Time: 16s | Loss: 2.2955 | Val Loss: 1.8525 | Val Acc: 66.61% | Val Top5: 90.25% | LR: 0.10064
# >>> Melhor modelo salvo! Acurácia: 66.61%
# Epoch [46/100] | Time: 16s | Loss: 2.2773 | Val Loss: 1.8982 | Val Acc: 65.18% | Val Top5: 89.06% | LR: 0.09816
# Epoch [47/100] | Time: 16s | Loss: 2.2708 | Val Loss: 1.9140 | Val Acc: 65.59% | Val Top5: 88.44% | LR: 0.09566
# Epoch [48/100] | Time: 17s | Loss: 2.2217 | Val Loss: 1.9909 | Val Acc: 62.13% | Val Top5: 87.28% | LR: 0.09313
# Epoch [49/100] | Time: 16s | Loss: 2.1547 | Val Loss: 1.8173 | Val Acc: 68.01% | Val Top5: 90.01% | LR: 0.09058
# >>> Melhor modelo salvo! Acurácia: 68.01%
# Epoch [50/100] | Time: 17s | Loss: 2.1584 | Val Loss: 1.8830 | Val Acc: 65.85% | Val Top5: 89.44% | LR: 0.08801
# Epoch [51/100] | Time: 16s | Loss: 2.2013 | Val Loss: 1.8123 | Val Acc: 68.65% | Val Top5: 91.07% | LR: 0.08543
# >>> Melhor modelo salvo! Acurácia: 68.65%
# Epoch [52/100] | Time: 16s | Loss: 2.1237 | Val Loss: 1.8087 | Val Acc: 67.88% | Val Top5: 90.32% | LR: 0.08283
# Epoch [53/100] | Time: 16s | Loss: 2.1154 | Val Loss: 1.7805 | Val Acc: 69.05% | Val Top5: 91.74% | LR: 0.08022
# >>> Melhor modelo salvo! Acurácia: 69.05%
# Epoch [54/100] | Time: 16s | Loss: 2.1071 | Val Loss: 1.7330 | Val Acc: 70.09% | Val Top5: 92.00% | LR: 0.07760
# >>> Melhor modelo salvo! Acurácia: 70.09%
# Epoch [55/100] | Time: 16s | Loss: 2.1715 | Val Loss: 1.8463 | Val Acc: 67.15% | Val Top5: 91.37% | LR: 0.07499
# Epoch [56/100] | Time: 16s | Loss: 2.0437 | Val Loss: 1.7796 | Val Acc: 68.65% | Val Top5: 91.44% | LR: 0.07237
# Epoch [57/100] | Time: 16s | Loss: 2.2058 | Val Loss: 1.7802 | Val Acc: 68.86% | Val Top5: 90.85% | LR: 0.06976
# Epoch [58/100] | Time: 16s | Loss: 2.2062 | Val Loss: 1.7461 | Val Acc: 69.66% | Val Top5: 91.96% | LR: 0.06715
# Epoch [59/100] | Time: 16s | Loss: 2.1051 | Val Loss: 1.7232 | Val Acc: 70.16% | Val Top5: 91.86% | LR: 0.06455
# >>> Melhor modelo salvo! Acurácia: 70.16%
# Epoch [60/100] | Time: 16s | Loss: 2.0811 | Val Loss: 1.6925 | Val Acc: 71.22% | Val Top5: 92.36% | LR: 0.06196
# >>> Melhor modelo salvo! Acurácia: 71.22%
# Epoch [61/100] | Time: 16s | Loss: 2.2088 | Val Loss: 1.6523 | Val Acc: 72.63% | Val Top5: 93.30% | LR: 0.05939
# >>> Melhor modelo salvo! Acurácia: 72.63%
# Epoch [62/100] | Time: 16s | Loss: 2.1456 | Val Loss: 1.7971 | Val Acc: 68.82% | Val Top5: 91.46% | LR: 0.05684
# Epoch [63/100] | Time: 16s | Loss: 2.0286 | Val Loss: 1.7113 | Val Acc: 71.30% | Val Top5: 92.45% | LR: 0.05432
# Epoch [64/100] | Time: 16s | Loss: 2.0607 | Val Loss: 1.7040 | Val Acc: 71.40% | Val Top5: 92.22% | LR: 0.05181
# Epoch [65/100] | Time: 16s | Loss: 2.1235 | Val Loss: 1.7256 | Val Acc: 70.68% | Val Top5: 91.81% | LR: 0.04934
# Epoch [66/100] | Time: 16s | Loss: 2.0357 | Val Loss: 1.6609 | Val Acc: 72.94% | Val Top5: 92.85% | LR: 0.04689
# >>> Melhor modelo salvo! Acurácia: 72.94%
# Epoch [67/100] | Time: 16s | Loss: 1.9590 | Val Loss: 1.7160 | Val Acc: 70.93% | Val Top5: 91.50% | LR: 0.04448
# Epoch [68/100] | Time: 16s | Loss: 2.0067 | Val Loss: 1.6006 | Val Acc: 74.08% | Val Top5: 93.47% | LR: 0.04211
# >>> Melhor modelo salvo! Acurácia: 74.08%
# Epoch [69/100] | Time: 16s | Loss: 1.9961 | Val Loss: 1.6378 | Val Acc: 73.18% | Val Top5: 92.82% | LR: 0.03978
# Epoch [70/100] | Time: 16s | Loss: 2.0661 | Val Loss: 1.6018 | Val Acc: 74.51% | Val Top5: 93.57% | LR: 0.03749
# >>> Melhor modelo salvo! Acurácia: 74.51%
# Epoch [71/100] | Time: 16s | Loss: 1.9336 | Val Loss: 1.6569 | Val Acc: 72.54% | Val Top5: 92.82% | LR: 0.03525
# Epoch [72/100] | Time: 16s | Loss: 1.9949 | Val Loss: 1.5896 | Val Acc: 74.74% | Val Top5: 93.88% | LR: 0.03305
# >>> Melhor modelo salvo! Acurácia: 74.74%
# Epoch [73/100] | Time: 17s | Loss: 1.9217 | Val Loss: 1.6571 | Val Acc: 72.67% | Val Top5: 93.08% | LR: 0.03091
# Epoch [74/100] | Time: 16s | Loss: 2.0061 | Val Loss: 1.6366 | Val Acc: 73.42% | Val Top5: 92.79% | LR: 0.02882
# Epoch [75/100] | Time: 16s | Loss: 1.8852 | Val Loss: 1.5895 | Val Acc: 74.87% | Val Top5: 93.38% | LR: 0.02678
# >>> Melhor modelo salvo! Acurácia: 74.87%
# Epoch [76/100] | Time: 16s | Loss: 1.8649 | Val Loss: 1.5446 | Val Acc: 75.95% | Val Top5: 94.43% | LR: 0.02481
# >>> Melhor modelo salvo! Acurácia: 75.95%
# Epoch [77/100] | Time: 16s | Loss: 1.8906 | Val Loss: 1.5172 | Val Acc: 76.86% | Val Top5: 94.33% | LR: 0.02289
# >>> Melhor modelo salvo! Acurácia: 76.86%
# Epoch [78/100] | Time: 16s | Loss: 1.8198 | Val Loss: 1.5456 | Val Acc: 76.64% | Val Top5: 93.95% | LR: 0.02104
# Epoch [79/100] | Time: 16s | Loss: 1.8663 | Val Loss: 1.4984 | Val Acc: 77.68% | Val Top5: 94.64% | LR: 0.01926
# >>> Melhor modelo salvo! Acurácia: 77.68%
# Epoch [80/100] | Time: 17s | Loss: 1.7618 | Val Loss: 1.5145 | Val Acc: 76.63% | Val Top5: 94.22% | LR: 0.01754
# Epoch [81/100] | Time: 17s | Loss: 1.6671 | Val Loss: 1.5011 | Val Acc: 77.57% | Val Top5: 94.66% | LR: 0.01589
# Epoch [82/100] | Time: 16s | Loss: 1.6651 | Val Loss: 1.4595 | Val Acc: 78.99% | Val Top5: 94.91% | LR: 0.01432
# >>> Melhor modelo salvo! Acurácia: 78.99%
# Epoch [83/100] | Time: 17s | Loss: 1.6887 | Val Loss: 1.4590 | Val Acc: 78.66% | Val Top5: 95.00% | LR: 0.01282
# Epoch [84/100] | Time: 16s | Loss: 1.6428 | Val Loss: 1.4558 | Val Acc: 78.96% | Val Top5: 95.02% | LR: 0.01139
# Epoch [85/100] | Time: 17s | Loss: 1.6522 | Val Loss: 1.4280 | Val Acc: 79.48% | Val Top5: 95.25% | LR: 0.01004
# >>> Melhor modelo salvo! Acurácia: 79.48%
# Epoch [86/100] | Time: 17s | Loss: 1.6491 | Val Loss: 1.4361 | Val Acc: 79.93% | Val Top5: 95.11% | LR: 0.00877
# >>> Melhor modelo salvo! Acurácia: 79.93%
# Epoch [87/100] | Time: 17s | Loss: 1.6172 | Val Loss: 1.4183 | Val Acc: 80.17% | Val Top5: 95.38% | LR: 0.00759
# >>> Melhor modelo salvo! Acurácia: 80.17%
# Epoch [88/100] | Time: 17s | Loss: 1.6659 | Val Loss: 1.3979 | Val Acc: 81.01% | Val Top5: 95.52% | LR: 0.00648
# >>> Melhor modelo salvo! Acurácia: 81.01%
# Epoch [89/100] | Time: 16s | Loss: 1.6360 | Val Loss: 1.3855 | Val Acc: 81.15% | Val Top5: 95.77% | LR: 0.00546
# >>> Melhor modelo salvo! Acurácia: 81.15%
# Epoch [90/100] | Time: 16s | Loss: 1.6214 | Val Loss: 1.3840 | Val Acc: 81.60% | Val Top5: 95.93% | LR: 0.00452
# >>> Melhor modelo salvo! Acurácia: 81.60%
# Epoch [91/100] | Time: 16s | Loss: 1.5576 | Val Loss: 1.3524 | Val Acc: 82.15% | Val Top5: 96.04% | LR: 0.00367
# >>> Melhor modelo salvo! Acurácia: 82.15%
# Epoch [92/100] | Time: 16s | Loss: 1.5184 | Val Loss: 1.3666 | Val Acc: 81.87% | Val Top5: 96.00% | LR: 0.00290
# Epoch [93/100] | Time: 16s | Loss: 1.4821 | Val Loss: 1.3424 | Val Acc: 82.56% | Val Top5: 96.07% | LR: 0.00223
# >>> Melhor modelo salvo! Acurácia: 82.56%
# Epoch [94/100] | Time: 17s | Loss: 1.4761 | Val Loss: 1.3438 | Val Acc: 82.92% | Val Top5: 96.12% | LR: 0.00164
# >>> Melhor modelo salvo! Acurácia: 82.92%
# Epoch [95/100] | Time: 17s | Loss: 1.4905 | Val Loss: 1.3372 | Val Acc: 83.28% | Val Top5: 96.04% | LR: 0.00114
# >>> Melhor modelo salvo! Acurácia: 83.28%
# Epoch [96/100] | Time: 16s | Loss: 1.4581 | Val Loss: 1.3385 | Val Acc: 83.08% | Val Top5: 96.12% | LR: 0.00073
# Epoch [97/100] | Time: 16s | Loss: 1.4430 | Val Loss: 1.3335 | Val Acc: 83.17% | Val Top5: 96.13% | LR: 0.00041
# Epoch [98/100] | Time: 16s | Loss: 1.4827 | Val Loss: 1.3489 | Val Acc: 83.19% | Val Top5: 96.07% | LR: 0.00018
# Epoch [99/100] | Time: 16s | Loss: 1.4323 | Val Loss: 1.3374 | Val Acc: 83.23% | Val Top5: 96.04% | LR: 0.00005
# Epoch [100/100] | Time: 16s | Loss: 1.4641 | Val Loss: 1.3366 | Val Acc: 83.20% | Val Top5: 96.10% | LR: 0.00000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from torchmetrics import ConfusionMatrix

# Carregar o melhor modelo
model.load_state_dict(torch.load('best_wrn28_10_cifar100.pth'))
model.eval()

confmat = ConfusionMatrix(task="multiclass", num_classes=100).to(device)
accuracy_metric.reset()
top5_accuracy_metric.reset()

with torch.no_grad():
    for inputs, targets in test_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        confmat.update(outputs, targets)
        accuracy_metric.update(outputs, targets)
        top5_accuracy_metric.update(outputs, targets)

cm = confmat.compute().cpu().numpy()
final_acc = accuracy_metric.compute().item() * 100
final_top5 = top5_accuracy_metric.compute().item() * 100

print(f"\n--- RESULTADOS FINAIS ---")
print(f"Melhor Top-1 Accuracy: {final_acc:.2f}%")
print(f"Melhor Top-5 Accuracy: {final_top5:.2f}%")

plt.figure(figsize=(20, 20))
sns.heatmap(cm, cmap='Blues', annot=False, xticklabels=False, yticklabels=False)
plt.title('Confusion Matrix - CIFAR-100', fontsize=16)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Running cells with 'Python 3.14.4' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
